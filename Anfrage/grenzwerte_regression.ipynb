# %% [markdown]
# # 🪐 Grenzwerte herausfinden & Regressionsanalyse
#
#
# - Grenzwerte verstehen und grafisch sichtbar machen
# - Erste Regressionsanalyse mit Python und scipy

# %% [markdown]
# ## ✏️ Teil 1: Grenzwerte herausfinden
#
# **Was sind Grenzwerte?**
#
# - Ein Grenzwert beschreibt, was mit einer Funktion passiert, wenn `x` gegen einen bestimmten Wert oder gegen unendlich läuft.
# - Beispiel:
#   - \( \lim_{x \to \infty} \frac{1}{x} = 0 \)
#   - \( \lim_{x \to 0^+} \frac{1}{x} = \infty \)
#   ![image.png](attachment:image.png)

# %%
# Beispiel: Grenzwert grafisch sichtbar machen
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.01, 2, 100)
y = 1 / x

plt.plot(x, y)
plt.title('Grafische Annäherung an den Grenzwert von 1/x für x -> 0')
plt.xlabel('x')
plt.ylabel('1/x')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Berechnung von Grenzwerten mit `sympy`
# Nutze `sympy`, um Grenzwerte symbolisch zu berechnen.

# %%
# %conda install sympy
# Out:
# Channels:
#  - conda-forge
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\brot\.conda\envs\pyseminar
#
#   added / updated specs:
#     - sympy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.7.9   |       h4c7d964_0         149 KB  conda-forge
#     mpmath-1.3.0               |     pyhd8ed1ab_1         429 KB  conda-forge
#     sympy-1.14.0               |     pyh04b8f61_5         4.4 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_1
#   sympy              conda-forge/noarch::sympy-1.14.0-pyh04b8f61_5
#
# The following packages will be UPDATED:
#
# ...

# %%
from sympy import Symbol, limit

x = Symbol('x')
expr = 1 / x

lim_0_plus = limit(expr, x, 0, '+')
lim_inf = limit(expr, x, float('inf'))

print(f'Grenzwert für x -> 0+: {lim_0_plus}')
print(f'Grenzwert für x -> ∞: {lim_inf}')
# Out:
# Grenzwert für x -> 0+: oo
# Grenzwert für x -> ∞: 0

# %% [markdown]
# ## ✏️ Teil 2: Regressionsanalyse
#
# **Was ist Regressionsanalyse?**
#
# - Ein Verfahren, um einen funktionalen Zusammenhang zwischen Variablen zu finden.
# - Einfachste Form: **lineare Regression** \( y = m \cdot x + b \ )![image.png](attachment:image.png)
# - Hilft Trends zu erkennen und Vorhersagen zu treffen.

# %%
# Einfaches Beispiel: Lineare Regression
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Regressionsanalyse
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

print(f'Steigung: {slope:.2f}')
print(f'Achsenabschnitt: {intercept:.2f}')
print(f'Korrelationskoeffizient: {r_value:.2f}')

# Trendlinie
line = slope * x + intercept

plt.scatter(x, y, label='Datenpunkte')
plt.plot(x, line, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.title('Lineare Regression')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
